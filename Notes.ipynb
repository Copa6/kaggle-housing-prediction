# %% [markdown]
# ## From Information
# * Utilities - Check skewness - Skewed, drop
# * Landslope - Skewness
# * Condition2 - Check if most are 'Normal' - Check if it can be clubbed with condition1
# * OverallQual - Check Significance
# * OverallCond - Check sig
# * YearBuilt + YearRemodAdd + Overallcond - General age + quality of the house
# * RoofMat - Check corr with overallQual
# * Exterior1st - Check corr with overallQual
# * Exterior2nd - Check availability of data
# * ExteriorQual + OverallQual check?
# * ExterCond - Check significance. Can be clubbed with interior cond or over condition
# * Foundation - Check significance
# * BasementQual + BasementCond - Check skew and significance
# * Bsmt - Check all vars
# * HeatingQC - Overall cond
# * KitchenQual - Overall quality
# * Checked - Bedroom, TotRmsAbvGrd - Combined: Bedrooms per room
# * GarageCars, GarageArea - Can be combined
# * GarageQual - Overall Qual
# * GarageQual + GarageCond - Check relation
# * PoolQC, FenceQC
# * MiscVal
# * MoSold, YrSold

# %% [markdown]
# ## Checked
# * Checked - Bedroom, TotRmsAbvGrd - Combined: Bedrooms per room
# * GarageCars, GarageArea - Can be combined
# * No need to check - GarageQual - Overall Qual
#
# #### Drop
# * Utilities
# * Condition2
#
#
# #### check 2
# * LandSlope
# * OverallCond
# * YearBuilt + YearRemodAdd + Overallcond - General age + quality of the house

# %% [markdown]
# ## From value distribution
# #### Uniform
# * Neighborhood
# * HouseStyle
# * Exterior1st
# * Exterior2nd
# * MasVnrType
# * Foundation(2 categories)
# * BsmtQual (2 categories)
# * BsmtFinType1
#
#
# * BsmtExposure
# * HeatingQC
# * KitchenQual
# * FireplaceQu
# * GarageType
# * GarageFinish
#
# #### Skewed
# * MSZoning - Skewed to RL - Check significance
# * Street -  Skewed to Pave - Check sig
# * LotShape - IR2, IR3 few vals
# * LandContour - Skewed Lvl
# * Utilities - Skewed AllPub. Only 1 NoSeWa
# * LotConfig - Skewed
# * LandSlope - skewed
# * Condition1 - skewed
# * Condition2 - Highly skewed
# * ExtrQual
# * ExtrCond
# * BsmtCond
# * BsmtFinType2
# * Heating
# * CentralAir
# * Electrical
# * Functional
# * GarageQual
# * PavedDrive
# * SaleType
# * SaleCondition
#
# #### Too few values
# * Alley - Too few values(50+41)
# * PoolQC
# * Fence
# * MiscFeature

# %% [markdown]
# ## From Plots
# #### Observations
# **Skewed**
# * Street
# * Alley
# * Utilities
# * Condition2
# * RoofStyle
# * RoofMat
# *
# * BsmtHalfBath
#
#  ---
# **Check**
# * MSZoning
# * LotShape
# * LandContour
# * LotConfig
# * LandSlope
# * Condition1
# * Exterior1st
# * Exterior2nd
# *
# * BedroomAbvGr
# * HalfBath
# * LotArea
# * FullBath
# * OverallCond
# * BsmtFullBath
# * Fireplaces
# * WoodDeckSF
# * MoSold
# * BsmtFinSF1
#
#  ---
#
# **Use**
# * Neighborhood
# * BldgType
# * HouseStyle
# *
# * GrLivArea
# * GarageCars
# * LotFrontage
# * OverallQual
# * GarageYrBlt
# * 1stFlrSF
# * 2ndFlrSF
# * TotRmsAbvGrd
# * GarageArea
# * MasVnrArea
# * YearBuilt
# * TotalBsmtSF
